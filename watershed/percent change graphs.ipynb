# %%
import pandas as pd

# %%
df = pd.read_csv('results/predictions.csv', index_col=0)

# %%
df
# Out:
#        FLOW_OUTcms   EVAPcms  TLOSScms  SED_OUTtons  SEDCONCmgL  ORGN_OUTkg  \
# -0.50    -0.083599 -0.019781  0.009939    -0.013326    0.018919    0.030991
# -0.45    -0.078924 -0.018226  0.006595    -0.010226    0.018919    0.030991
# -0.40    -0.077159 -0.013044  0.004900    -0.010226    0.013937    0.005608
# -0.35    -0.077159 -0.006710  0.004900    -0.010226    0.013937    0.005608
# -0.30    -0.077159 -0.006710  0.003901    -0.010226    0.013937    0.005608
# -0.25    -0.077159 -0.005538  0.003901    -0.010226    0.013937    0.007118
# -0.20    -0.033189 -0.004538  0.003809    -0.009305    0.013937    0.006518
# -0.15    -0.020964 -0.003962  0.002323    -0.008799    0.003909    0.001444
# -0.10    -0.013635 -0.001910  0.001590    -0.008799    0.003444    0.001433
# -0.05    -0.013635 -0.002905  0.001192    -0.008799    0.001890    0.000711
#  0.00     0.000000  0.000000  0.000000     0.000000    0.000000    0.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("paper")

# %%
g = sns.FacetGrid(data=df, col=df.columns, col_wrap=4, height=2, ylim=(0, 20))
# Out:
# ---------------------------------------
# AttributeErrorTraceback (most recent call last)
# ~/.local/share/virtualenvs/watershed-EG5ajtUt/lib/python3.6/site-packages/seaborn/utils.py in categorical_order(values, order)
#     525             try:
# --> 526                 order = values.cat.categories
#     527             except (TypeError, AttributeError):
#
# ~/.local/share/virtualenvs/watershed-EG5ajtUt/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeErrorTraceback (most recent call last)
# ~/.local/share/virtualenvs/watershed-EG5ajtUt/lib/python3.6/site-packages/seaborn/utils.py in categorical_order(values, order)
#     528                 try:
# ...

# %%
att = sns.load_dataset("attention")
att
# Out:
#     Unnamed: 0  subject attention  solutions  score
# 0            0        1   divided          1    2.0
# 1            1        2   divided          1    3.0
# 2            2        3   divided          1    3.0
# 3            3        4   divided          1    5.0
# 4            4        5   divided          1    4.0
# 5            5        6   divided          1    5.0
# 6            6        7   divided          1    5.0
# 7            7        8   divided          1    5.0
# 8            8        9   divided          1    2.0
# 9            9       10   divided          1    6.0
# 10          10       11   focused          1    6.0
# 11          11       12   focused          1    8.0
# 12          12       13   focused          1    6.0
# 13          13       14   focused          1    8.0
# 14          14       15   focused          1    8.0
# 15          15       16   focused          1    6.0
# 16          16       17   focused          1    7.0
# ...
