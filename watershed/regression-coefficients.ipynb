# %%
import pandas as pd

# %%
df = pd.read_csv('results/regression_coefficients.csv', index_col=0)

# %%
df
# Out:
#              FOREST_COVER1      PCP1  FOREST_COVER2      PCP2  FOREST_COVER3  \
# FLOW_OUTcms       0.000145  0.001694       0.000637  0.016317       0.000623
# EVAPcms           0.000037  0.004346       0.000092  0.019393       0.000084
# TLOSScms          0.000020  0.002812       0.000029  0.019460       0.000024
# SED_OUTtons       0.000165  0.056335       0.000137  0.018609       0.000338
# SEDCONCmgL        0.000041  0.050738       0.000053  0.020083       0.000075
# ORGN_OUTkg        0.000475  0.050065       0.000142  0.054292       0.000264
# ORGP_OUTkg        0.000543  0.000238       0.000919  0.028756       0.004874
# NO3_OUTkg         0.000103  0.049185       0.000056  0.020740       0.000323
# NH4_OUTkg         0.000110  0.012635       0.000060  0.026320       0.000258
# NO2_OUTkg         0.000535  0.028328       0.001243  0.021269       0.000253
# MINP_OUTkg        0.000093  0.015350       0.000209  0.032038       0.001774
# ...
